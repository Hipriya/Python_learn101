# %%
gdf = df.groupBy(df.name)
gdf.agg({"*": "count"}).collect()
[Row(name=u'Alice', count(1)=1), Row(name=u'Bob', count(1)=1)]

# %%
gdf= df.groupBy(df.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 gdf= df.groupBy(df.name)
#
# NameError: name 'df' is not defined

# %%
gdf.agg({"*":"count"}).collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gdf.agg({"*":"count"}).collect()
#
# NameError: name 'gdf' is not defined

# %%
>>> from pyspark.sql import Row
>>> df = sc.parallelize([Row(name='Alice', age=5, height=80),Row(name='Alice', age=5, height=80),Row(name='Alice', age=10, height=80)]).toDF()
>>> df.dropDuplicates().show()

# %%
conda install pyspark
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\PRISR\AppData\Local\anaconda3
#
#   added / updated specs:
#     - pyspark
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.12.12 |       haa95532_0         127 KB
#     certifi-2023.11.17         |  py311haa95532_0         160 KB
#     openssl-3.0.12             |       h2bbff1b_0         7.4 MB
#     py4j-0.10.9.7              |  py311haa95532_0         306 KB
#     pyspark-3.4.1              |  py311haa95532_0       292.8 MB
#     ------------------------------------------------------------
#                                            Total:       300.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   py4j               pkgs/main/win-64::py4j-0.10.9.7-py311haa95532_0
#   pyspark            pkgs/main/win-64::pyspark-3.4.1-py311haa95532_0
#
# ...

# %%
conda install -c conda-forge findspark
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\PRISR\AppData\Local\anaconda3
#
#   added / updated specs:
#     - findspark
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.11.17 |       h56e8100_0         151 KB  conda-forge
#     certifi-2023.11.17         |     pyhd8ed1ab_0         155 KB  conda-forge
#     findspark-2.0.1            |     pyhd8ed1ab_0           8 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         314 KB
#
# The following NEW packages will be INSTALLED:
#
#   findspark          conda-forge/noarch::findspark-2.0.1-pyhd8ed1ab_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
# ...

# %%
arr=[56,89,9,23,11,54,78,36]

# %%
arr1=[11,25,55,66,99]

# %%
mid=arr1[0]+arr[len(arr)]

# %%
def binarysearch(arr,high, low, num):
    mid=(low+high)/2
    if mid==num:
        return mid
    elif arr[mid]>num:
        return
    elif arr[mid]< num:
        return arr[mid]<x

# %%
arr=[11,25,25,55,66,66,99]

# %%
def removeduplicate(arr):
    newarr=[]
    count=0
    num=arr[0]
    for i in range(len(arr)):
        num=arr[0]
        if arr[0]==arr[i]:
            count=count+1
            newarr=newarr.append(arr[i])
            print(newarr)
        else:
            num=arr[i]
    return newarr

# %%
arr=[11,25,25,55,66,66,99]

# %%
def removedups(arr):
    newarr=[]
    for num in arr:
        if num not  in newarr:
            newarr.append(num)
    
    return newarr

# %%
removedups(arr)
# Out:
# []

# %%
# Out:
# [11, 25, 55, 66, 99]
